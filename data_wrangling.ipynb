# %%
import pandas as pd

# %%
df.shape
# Out:
# (205, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order_ID     205 non-null    int64
#  1   Customer_ID  205 non-null    int64
#  2   Gender       162 non-null    object
#  3   Age          96 non-null     float64
#  4   Product      205 non-null    object
#  5   Quantity     205 non-null    int64
#  6   Unit_Price   205 non-null    int64
#  7   Order_Date   205 non-null    datetime64[ns]
#  8   Country      205 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 14.5+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer_ID      0
# Gender          43
# Age            109
# Product          0
# Quantity         0
# Unit_Price       0
# Order_Date       0
# Country          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order_ID     205 non-null    int64
#  1   Customer_ID  205 non-null    int64
#  2   Gender       162 non-null    object
#  3   Age          96 non-null     float64
#  4   Product      205 non-null    object
#  5   Quantity     205 non-null    int64
#  6   Unit_Price   205 non-null    int64
#  7   Order_Date   205 non-null    datetime64[ns]
#  8   Country      205 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 14.5+ KB

# %%
 df.duplicated().sum()
# Out:
# 5

# %%
df.describe()
# Out:
#          Order_ID  Customer_ID        Age    Quantity   Unit_Price
# count  205.000000   205.000000  96.000000  205.000000   205.000000
# mean    98.121951  1051.195122  40.614583    2.760976  1030.731707
# std     59.120679    31.161360  12.481877    1.399033   375.711027
# min      1.000000  1000.000000  18.000000    1.000000   500.000000
# 25%     47.000000  1024.000000  29.750000    1.000000   800.000000
# 50%     98.000000  1049.000000  41.500000    3.000000  1200.000000
# 75%    149.000000  1081.000000  52.000000    4.000000  1500.000000
# max    200.000000  1100.000000  60.000000    5.000000  1500.000000

# %%
df.dtypes
# Out:
# Order_ID                int64
# Customer_ID             int64
# Gender                 object
# Age                   float64
# Product                object
# Quantity                int64
# Unit_Price              int64
# Order_Date     datetime64[ns]
# Country                object
# dtype: object

# %%
df['Gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'F', 'M'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['UK', 'USA', 'India', 'U.S.A', 'india'], dtype=object)

# %%
df.describe()
# Out:
#          Order_ID  Customer_ID        Age    Quantity   Unit_Price
# count  205.000000   205.000000  96.000000  205.000000   205.000000
# mean    98.121951  1051.195122  40.614583    2.760976  1030.731707
# std     59.120679    31.161360  12.481877    1.399033   375.711027
# min      1.000000  1000.000000  18.000000    1.000000   500.000000
# 25%     47.000000  1024.000000  29.750000    1.000000   800.000000
# 50%     98.000000  1049.000000  41.500000    3.000000  1200.000000
# 75%    149.000000  1081.000000  52.000000    4.000000  1500.000000
# max    200.000000  1100.000000  60.000000    5.000000  1500.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['Age'])
plt.show()

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
0
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer_ID      0
# Gender          42
# Age            106
# Product          0
# Quantity         0
# Unit_Price       0
# Order_Date       0
# Country          0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Gender'].fillna("Unknown", inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
5
# Out:
# 5

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
0
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Order_ID       0
# Customer_ID    0
# Gender         0
# Age            0
# Product        0
# Quantity       0
# Unit_Price     0
# Order_Date     0
# Country        0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df['Gender'].fillna("Unknown", inplace=True)

# %%
df.isnull().sum()
# Out:
# Order_ID       0
# Customer_ID    0
# Gender         0
# Age            0
# Product        0
# Quantity       0
# Unit_Price     0
# Order_Date     0
# Country        0
# dtype: int64

# %%
df.dtypes
# Out:
# Order_ID                int64
# Customer_ID             int64
# Gender                 object
# Age                   float64
# Product                object
# Quantity                int64
# Unit_Price              int64
# Order_Date     datetime64[ns]
# Country                object
# dtype: object

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df.dtypes
# Out:
# Order_ID                int64
# Customer_ID             int64
# Gender                 object
# Age                   float64
# Product                object
# Quantity                int64
# Unit_Price              int64
# Order_Date     datetime64[ns]
# Country                object
# dtype: object

# %%
datetime64[ns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 datetime64[ns]
#
# NameError: name 'datetime64' is not defined

# %%
df['Gender'] = df['Gender'].str.lower()

df['Gender'] = df['Gender'].replace({
    'm': 'male',
    'f': 'female'
})

# %%
df['Gender'].unique()
# Out:
# array(['male', 'unknown', 'female'], dtype=object)

# %%
df['Country'] = df['Country'].str.lower()

df['Country'] = df['Country'].replace({
    'u.s.a': 'usa'
})

# %%
df['Total_Sales'] = df['Quantity'] * df['Unit_Price']

# %%
df.head()
# Out:
#    Order_ID  Customer_ID   Gender       Age     Product  Quantity  Unit_Price  \
# 0         1         1081     male  40.43617       Phone         2         800
# 1         2         1011  unknown  45.00000      Laptop         1         800
# 2         3         1077     male  53.00000  Headphones         2        1500
# 3         4         1000   female  40.43617      Tablet         2         800
# 4         5         1011   female  40.43617      Tablet         5        1200
#
#   Order_Date Country  Total_Sales
# 0 2023-02-22      uk         1600
# 1 2023-04-30      uk          800
# 2 2023-10-29     usa         3000
# 3 2023-06-22   india         1600
# 4 2023-01-23     usa         6000

# %%
df['Age_Group'] = pd.cut(
    df['Age'],
    bins=[0, 18, 30, 45, 60, 100],
    labels=['Teen', 'Young Adult', 'Adult', 'Senior', 'Old']
)

# %%
df[['Age', 'Age_Group']].head()
# Out:
#         Age Age_Group
# 0  40.43617     Adult
# 1  45.00000     Adult
# 2  53.00000    Senior
# 3  40.43617     Adult
# 4  40.43617     Adult

# %%
df['Order_Month'] = df['Order_Date'].dt.month

# %%
df['Order_Month_Name'] = df['Order_Date'].dt.month_name()

# %%
df[['Order_Date', 'Order_Month_Name']].head()
# Out:
#   Order_Date Order_Month_Name
# 0 2023-02-22         February
# 1 2023-04-30            April
# 2 2023-10-29          October
# 3 2023-06-22             June
# 4 2023-01-23          January

# %%
df.info()
df.isnull().sum()
df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          200 non-null    int64
#  1   Customer_ID       200 non-null    int64
#  2   Gender            200 non-null    object
#  3   Age               200 non-null    float64
#  4   Product           200 non-null    object
#  5   Quantity          200 non-null    int64
#  6   Unit_Price        200 non-null    int64
#  7   Order_Date        200 non-null    datetime64[ns]
#  8   Country           200 non-null    object
#  9   Total_Sales       200 non-null    int64
#  10  Age_Group         200 non-null    category
#  11  Order_Month       200 non-null    int64
#  12  Order_Month_Name  200 non-null    object
# dtypes: category(1), datetime64[ns](1), float64(1), int64(6), object(4)
# memory usage: 20.7+ KB
# 0

# %%
df.to_csv("cleaned_sales_dataset.csv", index=False)

# %%
df.dtypes
# Out:
# Order_ID                     int64
# Customer_ID                  int64
# Gender                      object
# Age                        float64
# Product                     object
# Quantity                     int64
# Unit_Price                   int64
# Order_Date          datetime64[ns]
# Country                     object
# Total_Sales                  int64
# Age_Group                 category
# Order_Month                  int64
# Order_Month_Name            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Customer_ID         0
# Gender              0
# Age                 0
# Product             0
# Quantity            0
# Unit_Price          0
# Order_Date          0
# Country             0
# Total_Sales         0
# Age_Group           0
# Order_Month         0
# Order_Month_Name    0
# dtype: int64

# %%
0
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
0
# Out:
# 0

# %%
df.head()
# Out:
#    Order_ID  Customer_ID   Gender       Age     Product  Quantity  Unit_Price  \
# 0         1         1081     male  40.43617       Phone         2         800
# 1         2         1011  unknown  45.00000      Laptop         1         800
# 2         3         1077     male  53.00000  Headphones         2        1500
# 3         4         1000   female  40.43617      Tablet         2         800
# 4         5         1011   female  40.43617      Tablet         5        1200
#
#   Order_Date Country  Total_Sales Age_Group  Order_Month Order_Month_Name
# 0 2023-02-22      uk         1600     Adult            2         February
# 1 2023-04-30      uk          800     Adult            4            April
# 2 2023-10-29     usa         3000    Senior           10          October
# 3 2023-06-22   india         1600     Adult            6             June
# 4 2023-01-23     usa         6000     Adult            1          January

# %%
df.to_csv("cleaned_sales_dataset.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          200 non-null    int64
#  1   Customer_ID       200 non-null    int64
#  2   Gender            200 non-null    object
#  3   Age               200 non-null    float64
#  4   Product           200 non-null    object
#  5   Quantity          200 non-null    int64
#  6   Unit_Price        200 non-null    int64
#  7   Order_Date        200 non-null    datetime64[ns]
#  8   Country           200 non-null    object
#  9   Total_Sales       200 non-null    int64
#  10  Age_Group         200 non-null    category
#  11  Order_Month       200 non-null    int64
#  12  Order_Month_Name  200 non-null    object
# dtypes: category(1), datetime64[ns](1), float64(1), int64(6), object(4)
# memory usage: 20.7+ KB

# %%
df["Total_Sales"].sum()
# Out:
# 566600

# %%
df.groupby("Country")["Total_Sales"].sum().sort_values(ascending=False)
# Out:
# Country
# usa      275100
# india    192300
# uk        99200
# Name: Total_Sales, dtype: int64

# %%
df.groupby("Gender")["Total_Sales"].sum()
# Out:
# Gender
# female     243400
# male       216700
# unknown    106500
# Name: Total_Sales, dtype: int64

# %%
df.groupby("Age_Group")["Total_Sales"].sum().sort_values(ascending=False)
# Out:
# Age_Group
# Adult          376800
# Senior          91200
# Young Adult     91100
# Teen             7500
# Old                 0
# Name: Total_Sales, dtype: int64

# %%
df.groupby("Product")["Total_Sales"].sum().sort_values(ascending=False)
# Out:
# Product
# Phone         177100
# Tablet        153200
# Headphones    123800
# Laptop        112500
# Name: Total_Sales, dtype: int64

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Gender', 'Age', 'Product', 'Quantity',
#        'Unit_Price', 'Order_Date', 'Country', 'Total_Sales', 'Age_Group',
#        'Order_Month', 'Order_Month_Name'],
#       dtype='object')

# %%
df.groupby("Order_Month_Name")["Total_Sales"].sum().sort_values()
# Out:
# Order_Month_Name
# May          17400
# September    23500
# March        24900
# January      26200
# July         28700
# April        42100
# February     54000
# December     57100
# October      65000
# November     71200
# June         72100
# August       84400
# Name: Total_Sales, dtype: int64

# %%
monthly_sales = df.groupby("Order_Month_Name")["Total_Sales"].sum()

import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
monthly_sales.plot(kind="bar")
plt.title("Monthly Sales Trend")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()
